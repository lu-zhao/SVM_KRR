# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
filename = os.path.join('data', "Sodermalmsallen4-6.csv")
df = pd.read_csv(filename,sep=',')
df = df.set_index('Date_Time')
df.head()
# Out:
#                      year  month  day  hour  week  weekday  weekday_  \
# Date_Time
# 2018-08-23 07:00:00  2018      8   23     7    33        4         1
# 2018-08-23 08:00:00  2018      8   23     8    33        4         1
# 2018-08-23 09:00:00  2018      8   23     9    33        4         1
# 2018-08-23 10:00:00  2018      8   23    10    33        4         1
# 2018-08-23 11:00:00  2018      8   23    11    33        4         1
#
#                      Consumption  one_hour_before  two_hour_before  \
# Date_Time
# 2018-08-23 07:00:00         6.04             3.24             3.74
# 2018-08-23 08:00:00        16.19             6.04             3.24
# 2018-08-23 09:00:00        16.96            16.19             6.04
# 2018-08-23 10:00:00        12.59            16.96            16.19
# 2018-08-23 11:00:00        16.95            12.59            16.96
#
#                      three_hour_before  1days_before  2days_before  \
# Date_Time
# 2018-08-23 07:00:00               4.74         10.48          4.44
# 2018-08-23 08:00:00               3.74         11.72          5.20
# 2018-08-23 09:00:00               3.24          6.92          4.88
# 2018-08-23 10:00:00               6.04          6.25          5.18
# 2018-08-23 11:00:00              16.19         11.37          5.78
#
#                      7days_before  weather
# Date_Time
# 2018-08-23 07:00:00          5.88     17.8
# 2018-08-23 08:00:00         14.44     17.2
# 2018-08-23 09:00:00         13.00     18.0
# 2018-08-23 10:00:00          8.60     18.0
# 2018-08-23 11:00:00         12.65     18.4

# %% [markdown]
# # Correlations among features

# %%
df1 = df[['Consumption', 'hour','weekday','one_hour_before','two_hour_before',
         'three_hour_before','1days_before','2days_before','7days_before','weather']]

# %%
plt.matshow(df1.corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
plt.title('correlation between features', size=12)
plt.colorbar()
plt.show()

# %%
df1.corr(method='spearman')
# Out:
#                    Consumption      hour   weekday  one_hour_before  \
# Consumption           1.000000  0.328154 -0.069583         0.729874
# hour                  0.328154  1.000000  0.002260         0.398511
# weekday              -0.069583  0.002260  1.000000        -0.070029
# one_hour_before       0.729874  0.398511 -0.070029         1.000000
# two_hour_before       0.494158  0.430719 -0.068015         0.729975
# three_hour_before     0.373936  0.363463 -0.058434         0.494222
# 1days_before          0.445564  0.327254 -0.037628         0.384780
# 2days_before          0.420895  0.327072 -0.007933         0.371185
# 7days_before          0.445255  0.325976 -0.065183         0.382416
# weather               0.081942  0.124024  0.036725         0.085504
#
#                    two_hour_before  three_hour_before  1days_before  \
# Consumption               0.494158           0.373936      0.445564
# hour                      0.430719           0.363463      0.327254
# weekday                  -0.068015          -0.058434     -0.037628
# one_hour_before           0.729975           0.494222      0.384780
# two_hour_before           1.000000           0.729993      0.322624
# three_hour_before         0.729993           1.000000      0.295935
# 1days_before              0.322624           0.295935      1.000000
# 2days_before              0.312409           0.282966      0.445029
# 7days_before              0.309562           0.280305      0.411096
# weather                   0.075802           0.057824      0.087573
#
#                    2days_before  7days_before   weather
# Consumption            0.420895      0.445255  0.081942
# hour                   0.327072      0.325976  0.124024
# weekday               -0.007933     -0.065183  0.036725
# one_hour_before        0.371185      0.382416  0.085504
# two_hour_before        0.312409      0.309562  0.075802
# three_hour_before      0.282966      0.280305  0.057824
# 1days_before           0.445029      0.411096  0.087573
# 2days_before           1.000000      0.405785  0.089389
# 7days_before           0.405785      1.000000  0.123455
# weather                0.089389      0.123455  1.000000
